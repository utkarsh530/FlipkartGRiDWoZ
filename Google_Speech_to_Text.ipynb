# %%
import speech_recognition as sr

# obtain path to "english.wav" in the same folder as this script
import os
from os import path
import csv

# %%
converted_recordings = os.listdir("Converted_Recordings_Flipkart")
converted_recordings
# Out:
# ['0.wav',
#  '1.wav',
#  '10.wav',
#  '100.wav',
#  '101.wav',
#  '102.wav',
#  '103.wav',
#  '104.wav',
#  '105.wav',
#  '106.wav',
#  '107.wav',
#  '108.wav',
#  '109.wav',
#  '11.wav',
#  '110.wav',
#  '111.wav',
#  '112.wav',
#  '113.wav',
#  '114.wav',
#  '115.wav',
#  '116.wav',
#  '117.wav',
#  '118.wav',
#  '119.wav',
#  '12.wav',
#  '120.wav',
#  '121.wav',
#  '122.wav',
#  '123.wav',
#  '124.wav',
#  '125.wav',
#  '126.wav',
#  '127.wav',
#  '128.wav',
#  '129.wav',
#  '13.wav',
#  '130.wav',
#  '131.wav',
#  '132.wav',
#  '133.wav',
#  '134.wav',
#  '135.wav',
#  '136.wav',
#  '137.wav',
#  '138.wav',
#  '139.wav',
#  '14.wav',
#  '140.wav',
#  '141.wav',
#  '142.wav',
#  '143.wav',
#  '144.wav',
#  '145.wav',
#  '146.wav',
#  '147.wav',
#  '148.wav',
#  '149.wav',
#  '15.wav',
#  '150.wav',
#  '151.wav',
#  '152.wav',
#  '153.wav',
#  '154.wav',
#  '155.wav',
#  '156.wav',
#  '157.wav',
#  '158.wav',
#  '159.wav',
#  '16.wav',
#  '160.wav',
#  '161.wav',
#  '162.wav',
# ...

# %%
with open('transcripts_new.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["SN", "Transcript"])
    writer.writerow([j, transcript])

# %%
with open('innovators.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["SN", "Name", "Contribution"])
    writer.writerow([1, "Linus Torvalds", "Linux Kernel"])
    writer.writerow([2, "Tim Berners-Lee", "World Wide Web"])
    writer.writerow([3, "Guido van Rossum", "Python Programming"])

# %%
j = 1
with open('transcripts_new.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["SN", "Transcript"])
    for out_r in converted_recordings:

        AUDIO_FILE = "Converted_Recordings_Flipkart/"+out_r
        r = sr.Recognizer()
        with sr.AudioFile(AUDIO_FILE) as source:
            audio = r.record(source)  # read the entire audio file
            try:
            # for testing purposes, we're just using the default API key
            # to use another API key, use `r.recognize_google(audio, key="GOOGLE_SPEECH_RECOGNITION_API_KEY")`
            # instead of `r.recognize_google(audio)`
                transcript = r.recognize_google(audio)
                print("Google Speech Recognition thinks you said: " + transcript)
                writer.writerow([out_r[:-4], str(transcript)])     
            except sr.UnknownValueError:
                print("Google Speech Recognition could not understand audio")
            except sr.RequestError as e:
                print("Could not request results from Google Speech Recognition service; {0}".format(e))
            j+=1
# Out:
# Google Speech Recognition thinks you said: abe kal Mein Bada t-shirt Dal Do Khat Mein
# Google Speech Recognition thinks you said: fitness band chahie tha
# Google Speech Recognition thinks you said: Activa 4G kitne ka hai price kitna hai uska
# Google Speech Recognition thinks you said: how much is per yellow colour short kurti
# Google Speech Recognition thinks you said: Pehla biscuit ka packet basket Mein Dal Do
# Google Speech Recognition thinks you said: the sabun
# Google Speech Recognition thinks you said: Amar band ki rate dikhao
# Google Speech Recognition thinks you said: scented candles Mein Council seat available hai aapke pass
# Google Speech Recognition thinks you said: Nivea men artificial gold shower gel
# Google Speech Recognition thinks you said: Nokia phone screen touch
# Google Speech Recognition thinks you said: ka naam bataiye
# Google Speech Recognition thinks you said: 1 Rupee offer Vada groceries Flipkart
# ...
